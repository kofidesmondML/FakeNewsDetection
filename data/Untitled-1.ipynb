# %%
import pandas as pd

# %%
df=pd.read_csv('FakeNewsContent.csv')

# %%
df
# Out:
#      Unnamed: 0                                     canonical_link  \
# 0             0  http://now8news.com/united-airlines-flight-att...
# 1             1  http://ladylibertysnews.com/muslims-offended-k...
# 2             2  http://www.antinews.in/chinese-lunar-rover-fin...
# 3             3  http://alternativemediasyndicate.org/2017/04/0...
# 4             4  http://uspoln.com/2017/02/07/john-hagee-god-ma...
# ..          ...                                                ...
# 115         115  http://uspoln.com/2016/11/14/stephen-bannon-no...
# 116         116                                                NaN
# 117         117                                 http://uspoln.com/
# 118         118  https://obnoxioustelevision.com/2013/03/05/new...
# 119         119                                                NaN
#
#                                                authors  summary  \
# 0                                                   []      NaN
# ...

# %%
df['summary'].unique()
# Out:
# array([nan])

# %%
df1=pd.read_csv('RealNewsContent.csv')

# %%
df1
# Out:
#      Unnamed: 0                                     canonical_link  \
# 0             0  http://www.politico.com/story/2016/09/zika-fun...
# 1             1  http://occupydemocrats.com/2016/09/21/massive-...
# 2             2  http://rightwingnews.com/top-news/famous-dog-k...
# 3             3                                                NaN
# 4             4  http://www.politico.com/magazine/story/2016/09...
# ..          ...                                                ...
# 115         115  http://www.opposingviews.com/i/health/female-c...
# 116         116  http://addictinginfo.com/2016/09/20/hateful-ar...
# 117         117  http://money.cnn.com/2016/09/26/technology/tru...
# 118         118  http://addictinginfo.com/2016/09/23/early-voti...
# 119         119  http://www.politico.com/story/2016/09/donald-t...
#
#                                                authors  summary  \
# 0    ['Jack Shafer', 'Burgess Everett', 'Seung Min ...      NaN
# ...

# %%
df['meta_data'][0]
# Out:
# "{'shareaholic': {'site_name': 'Now8News', 'language': 'en-US', 'url': 'http://now8news.com/united-airlines-flight-attendant-slaps-crying-baby/', 'article_author_name': 'Now8News', 'image': 'http://now8news.com/wp-content/uploads/2017/04/united-airlines-bad-pr-1024x683.jpg', 'site_id': 'abe4da0665bb9d26b7c873380fbf0c58', 'article_published_time': '2017-04-10T23:33:37+00:00', 'shareable_page': 'true', 'article_modified_time': '2017-07-31T17:30:28+00:00', 'keywords': 'news', 'wp_version': '7.8.0.4'}, 'generator': 'WordPress 4.8.1', 'og': {'site_name': 'Now8News', 'description': 'During a flight from New York City to Chicago, violence erupted after a flight attendant assaulted a 7 month-old baby boy. This comes just hours after a man was dragged off of an overbooked United Airlines flight when he refused to get off the plane. He was pulled out of his seat and thrown into the', 'title': 'United Airlines Flight Attendant Slaps Crying Baby During Flight - Now8News', 'locale': 'en_US', 'ima
# ...
