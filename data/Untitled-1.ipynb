# %%
import pandas as pd

# %%
df=pd.read_csv('FakeNewsContent.csv')

# %%
df
# Out:
#                filename                                                url  \
# 0    PolitiFact_Fake_66  http://now8news.com/united-airlines-flight-att...
# 1    PolitiFact_Fake_33  http://ladylibertysnews.com/muslims-offended-k...
# 2    PolitiFact_Fake_99  http://www.antinews.in/chinese-lunar-rover-fin...
# 3    PolitiFact_Fake_61  http://alternativemediasyndicate.com/2017/04/0...
# 4    PolitiFact_Fake_34  http://uspoln.com/2017/02/07/john-hagee-god-ma...
# ..                  ...                                                ...
# 115  PolitiFact_Fake_40  http://uspoln.com/2016/11/14/stephen-bannon-no...
# 116  PolitiFact_Fake_12                                                NaN
# 117  PolitiFact_Fake_47  http://uspoln.com/2017/03/17/tom-price-better-...
# 118  PolitiFact_Fake_52  https://obnoxioustelevision.com/2013/03/05/new...
# 119  PolitiFact_Fake_55                                                NaN
#
#                                         canonical_link  \
# 0    http://now8news.com/united-airlines-flight-att...
# 1    http://ladylibertysnews.com/muslims-offended-k...
# 2    http://www.antinews.in/chinese-lunar-rover-fin...
# 3    http://alternativemediasyndicate.org/2017/04/0...
# 4    http://uspoln.com/2017/02/07/john-hagee-god-ma...
# ..                                                 ...
# 115  http://uspoln.com/2016/11/14/stephen-bannon-no...
# 116                                                NaN
# 117                                 http://uspoln.com/
# 118  https://obnoxioustelevision.com/2013/03/05/new...
# 119                                                NaN
#
#                                             movies  \
# 0                                               []
# 1    ['https://www.youtube.com/embed/UsmuPI6BJdI']
# 2                                               []
# 3                                               []
# 4                                               []
# ..                                             ...
# 115                                             []
# 116                                            NaN
# 117                                             []
# 118                                             []
# 119                                            NaN
#
#                                              meta_data  \
# 0    {'shareaholic': {'site_name': 'Now8News', 'lan...
# 1    {'ca_image': 'http://ladylibertysnews.com/wp-c...
# 2    {'ca_image': 'http://www.antinews.in/wp-conten...
# 3    {'generator': 'WordPress 4.8.1', 'og': {'site_...
# 4    {'generator': 'WordPress 4.8.1', 'og': {'site_...
# ..                                                 ...
# 115  {'generator': 'WordPress 4.8.1', 'og': {'site_...
# 116                                                NaN
# 117  {'og': {'locale': 'en_US', 'url': 'http://uspo...
# 118  {'generator': 'WordPress.com', 'application-na...
# 119                                                NaN
#
#                                                 images  \
# 0    ['http://now8news.com/wp-content/uploads/2017/...
# 1    ['http://ladylibertysnews.com/wp-content/uploa...
# 2    ['http://www.antinews.in/wp-content/uploads/20...
# 3    ['http://pixel.watch/lg99', 'http://cdn.altern...
# 4    ['http://uspoln.com/wp-content/uploads/2017/07...
# ..                                                 ...
# 115  ['http://uspoln.com/wp-content/uploads/2017/07...
# 116                                                NaN
# 117  ['http://uspoln.com/wp-content/uploads/2017/07...
# 118  ['https://2.gravatar.com/avatar/5a348e3fffffc9...
# 119                                                NaN
#
#                                                top_img  \
# 0    http://now8news.com/wp-content/uploads/2017/04...
# 1    http://ladylibertysnews.com/wp-content/uploads...
# 2    http://www.antinews.in/wp-content/uploads/2017...
# 3    http://cdn.alternativemediasyndicate.com/wp-co...
# 4    http://uspoln.com/wp-content/uploads/2017/02/1...
# ..                                                 ...
# 115  http://uspoln.com/wp-content/uploads/2016/11/S...
# 116                                                NaN
# 117  http://uspoln.com/wp-content/uploads/2017/07/B...
# 118  https://obnoxioustv.files.wordpress.com/2013/0...
# 119                                                NaN
#
#                                                authors keywords  \
# 0                                                   []       []
# 1                                      ['Todd Cooney']       []
# 2                                                   []       []
# 3                                                   []       []
# 4                                                   []       []
# ..                                                 ...      ...
# 115                                                 []       []
# 116                                                NaN      NaN
# 117                                                 []       []
# 118  ['John Smith', 'So Focused', 'Messy Mae', 'Fis...       []
# 119                                                NaN      NaN
#
#                  publish_date  summary                                source  \
# 0    {'$date': 1491867217000}      NaN                   http://now8news.com
# 1    {'$date': 1481570451000}      NaN           http://ladylibertysnews.com
# 2    {'$date': 1495366044000}      NaN                http://www.antinews.in
# 3    {'$date': 1491523200000}      NaN  http://alternativemediasyndicate.com
# 4    {'$date': 1486425600000}      NaN                     http://uspoln.com
# ..                        ...      ...                                   ...
# 115  {'$date': 1479081600000}      NaN                     http://uspoln.com
# 116                       NaN      NaN                                   NaN
# 117  {'$date': 1489708800000}      NaN                     http://uspoln.com
# 118  {'$date': 1362441600000}      NaN       https://obnoxioustelevision.com
# 119                       NaN      NaN                                   NaN
#
#                                                  title  \
# 0    United Airlines Flight Attendant Slaps Crying ...
# 1    Radical Muslims in Australia OFFENDED That The...
# 2    Chinese Lunar Rover Finds No Evidence Of Ameri...
# 3    Evangelical Leader Says Those Who Oppose Trump...
# 4    John Hagee Calls For “Prosecuting Women Who Sa...
# ..                                                 ...
# 115  “Nobody Can Blame You For Beating Your Wife If...
# 116  Breaking Crew Of Air Force One Refuses To Fly ...
# 117                                               Home
# 118  New York Man Wanted For Infecting 240 Men And ...
# 119  New Star Wars Movie Filming Near Rosenberg Tex...
#
#                                                   text
# 0    During a flight from New York City to Chicago,...
# 1    How intolerant can a group of people get, folk...
# 2    Chinese Lunar Rover Finds No Evidence Of Ameri...
# 3    Donald Trump may be an adulterer, he may be cr...
# 4    “One of the things that the Bible has consiste...
# ..                                                 ...
# 115  The recently installed CEO of Donald Trump was...
# 116  After eight years of flying to Chicago for Whi...
# 117                                                NaN
# 118  New York Man Wanted For Infecting 240 Men And ...
# 119  Backstage's auditions in Houston, Texas, inclu...
#
# [120 rows x 14 columns]

# %%
df['summary']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 115   NaN
# 116   NaN
# 117   NaN
# 118   NaN
# 119   NaN
# Name: summary, Length: 120, dtype: float64

# %%
df1=pd.read_csv('NewsContent.csv')

# %%
df1.columns
# Out:
# Index(['NewsID', 'filename', 'summary', 'text', 'movies', 'top_img',
#        'keywords', 'title', 'publish_date', 'source', 'canonical_link',
#        'images', 'url', 'authors', 'meta_data'],
#       dtype='object')

# %%
df['meta_data'][0]
# Out:
# "{'shareaholic': {'site_name': 'Now8News', 'language': 'en-US', 'url': 'http://now8news.com/united-airlines-flight-attendant-slaps-crying-baby/', 'article_author_name': 'Now8News', 'image': 'http://now8news.com/wp-content/uploads/2017/04/united-airlines-bad-pr-1024x683.jpg', 'site_id': 'abe4da0665bb9d26b7c873380fbf0c58', 'article_published_time': '2017-04-10T23:33:37+00:00', 'shareable_page': 'true', 'article_modified_time': '2017-07-31T17:30:28+00:00', 'keywords': 'news', 'wp_version': '7.8.0.4'}, 'generator': 'WordPress 4.8.1', 'og': {'site_name': 'Now8News', 'description': 'During a flight from New York City to Chicago, violence erupted after a flight attendant assaulted a 7 month-old baby boy. This comes just hours after a man was dragged off of an overbooked United Airlines flight when he refused to get off the plane. He was pulled out of his seat and thrown into the', 'title': 'United Airlines Flight Attendant Slaps Crying Baby During Flight - Now8News', 'locale': 'en_US', 'image': 'http://now8news.com/wp-content/uploads/2017/04/united-airlines-bad-pr.jpg', 'updated_time': '2017-04-10T23:33:37+00:00', 'url': 'http://now8news.com/united-airlines-flight-attendant-slaps-crying-baby/', 'type': 'article'}, 'twitter': {'url': 'http://now8news.com/united-airlines-flight-attendant-slaps-crying-baby/', 'image': 'http://now8news.com/wp-content/uploads/2017/04/united-airlines-bad-pr.jpg', 'description': 'During a flight from New York City to Chicago, violence erupted after a flight attendant assaulted a 7 month-old baby boy. This comes just hours after a man was dragged off of an overbooked United Airlines flight when he refused to get off the plane. He was pulled out of his seat and thrown into the', 'card': 'summary_large_image', 'title': 'United Airlines Flight Attendant Slaps Crying Baby During Flight - Now8News'}, 'msapplication-TileImage': 'http://now8news.com/wp-content/uploads/2016/09/cropped-cropped-LOGO_8_small-270x270.jpg', 'article': {'section': 'News', 'published_time': '2017-04-10T23:33:37+00:00', 'modified_time': '2017-04-10T23:33:37+00:00'}, 'viewport': 'width=device-width, initial-scale=1.0'}"

# %%
title='PolitiFact_Real_23-Webpage.json'

# %%
pip install ghananlp
# Out:
# ERROR: Could not find a version that satisfies the requirement ghananlp (from versions: none)
# ERROR: No matching distribution found for ghananlp
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy<2.0.0
# Out:
# zsh:1: no such file or directory: 2.0.0
# Note: you may need to restart the kernel to use updated packages.
